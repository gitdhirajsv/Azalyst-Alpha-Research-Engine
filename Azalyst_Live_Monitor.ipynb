# %% [markdown]
# # Azalyst Live Monitor
#
# Open this notebook from the Azalyst repo root and run the cells below while the autonomous team is active.
#
# - Cell 2 shows a one-time snapshot.
# - Cell 3 refreshes the same display object every few seconds without blocking Jupyter output rendering.
# - Stop the live loop with `Kernel -> Interrupt` in Jupyter.

# %%
from IPython.display import HTML, display
from pathlib import Path
import sys
import time

ROOT = Path.cwd()
if not (ROOT / "monitor_dashboard.py").exists():
    raise FileNotFoundError("Open this notebook from the Azalyst repo folder.")

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import monitor_dashboard as md

monitor = md.PipelineMonitor()
REFRESH_SECONDS = 5

# %%
display(HTML(md.build_dashboard_html(
    monitor.get_status(),
    auto_refresh_seconds=None,
    context_label="notebook",
)))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Azalyst Notebook</title>
#   <style>
#     :root {
#       --bg: #0b1220;
#       --panel: #111b2e;
#       --panel-2: #16243d;
#       --text: #d9f5e2;
#       --muted: #8fb7a0;
#       --accent: #21c16b;
#       --warn: #e0b34a;
#       --danger: #f0626e;
#       --border: rgba(143, 183, 160, 0.22);
#       --shadow: 0 18px 40px rgba(0, 0, 0, 0.25);
#     }
#     * { box-sizing: border-box; }
#     body {
#       margin: 0;
#       font-family: Consolas, "Courier New", monospace;
#       background:
#         radial-gradient(circle at top left, rgba(33, 193, 107, 0.16), transparent 28%),
#         radial-gradient(circle at top right, rgba(224, 179, 74, 0.10), transparent 24%),
#         var(--bg);
#       color: var(--text);
#     }
#     .page {
#       max-width: 1200px;
#       margin: 0 auto;
#       padding: 28px 20px 40px;
# ...

# %%
display_handle = display(HTML(md.build_dashboard_html(
    monitor.get_status(),
    auto_refresh_seconds=None,
    context_label="notebook",
)), display_id=True)

while True:
    display_handle.update(HTML(md.build_dashboard_html(
        monitor.get_status(),
        auto_refresh_seconds=None,
        context_label="notebook",
    )))
    time.sleep(REFRESH_SECONDS)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Azalyst Notebook</title>
#   <style>
#     :root {
#       --bg: #0b1220;
#       --panel: #111b2e;
#       --panel-2: #16243d;
#       --text: #d9f5e2;
#       --muted: #8fb7a0;
#       --accent: #21c16b;
#       --warn: #e0b34a;
#       --danger: #f0626e;
#       --border: rgba(143, 183, 160, 0.22);
#       --shadow: 0 18px 40px rgba(0, 0, 0, 0.25);
#     }
#     * { box-sizing: border-box; }
#     body {
#       margin: 0;
#       font-family: Consolas, "Courier New", monospace;
#       background:
#         radial-gradient(circle at top left, rgba(33, 193, 107, 0.16), transparent 28%),
#         radial-gradient(circle at top right, rgba(224, 179, 74, 0.10), transparent 24%),
#         var(--bg);
#       color: var(--text);
#     }
#     .page {
#       max-width: 1200px;
#       margin: 0 auto;
#       padding: 28px 20px 40px;
# ...
